# %% [markdown]
# <a href="https://colab.research.google.com/github/rishav2404/Data-Analysis/blob/main/Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Types of Analysis**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
# %matplotlib inline

# %%
telco_base_data = pd.read_csv('/content/Churn_Modelling.csv')

# %%
telco_base_data.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# Univariate

# %%
telco_new = telco_base_data[['Geography', 'Gender', 'Exited']]

# %%
telco_new.head(5)
# Out:
#   Geography  Gender  Exited
# 0    France  Female       1
# 1     Spain  Female       0
# 2    France  Female       1
# 3    France  Female       0
# 4     Spain  Female       0

# %%
telco_new.Exited.value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
telco_new.Exited.value_counts()/len(telco_new) * 100 #percentage of churn
# Out:
# Exited
# 0    79.63
# 1    20.37
# Name: count, dtype: float64

# %% [markdown]
# # **Univariate Analysis**

# %%
# sns.countplot(x='Geography', data=telco_new)
for i, predictor in  enumerate(telco_new.drop(columns='Exited')):
  plt.figure()
  sns.countplot(data=telco_new, x=predictor, hue='Exited')

# %% [markdown]
# # **Bivariate Analysis**

# %%
sns.histplot(x='Gender', hue='Geography', data=telco_new, stat='count' ,multiple='dodge')
# Out:
# <Axes: xlabel='Gender', ylabel='Count'>

# %%
# telco_new_target1 = telco_new.loc[telco_new.Exited == 1]
telco_new_target1 = telco_new.loc[telco_new['Exited'] == 1]

# %%
sns.histplot(x='Gender', hue='Geography', data=telco_new_target1, stat='count' ,multiple='dodge')
# Out:
# <Axes: xlabel='Gender', ylabel='Count'>

# %% [markdown]
# # **Numerical Analysis**

# %% [markdown]
# Correlation: It ranges from -1 to +1
#
# +1 —> Positive Correlation
#
# -1 —> Negative Correlation
#
# 0 —> No Correlation

# %%
# Select only numeric columns before calculating correlation
numeric_data = telco_base_data.select_dtypes(include=np.number)
correlation_matrix = numeric_data.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000783 -0.006495
# CustomerId        0.004202    1.000000     0.005308  0.009497 -0.014883
# CreditScore       0.005840    0.005308     1.000000 -0.003965  0.000842
# Age               0.000783    0.009497    -0.003965  1.000000 -0.009997
# Tenure           -0.006495   -0.014883     0.000842 -0.009997  1.000000
# Balance          -0.009067   -0.012419     0.006268  0.028308 -0.012254
# NumOfProducts     0.007246    0.016972     0.012238 -0.030680  0.013444
# HasCrCard         0.000599   -0.014025    -0.005458 -0.011721  0.022583
# IsActiveMember    0.012044    0.001665     0.025651  0.085472 -0.028362
# EstimatedSalary  -0.005988    0.015271    -0.001384 -0.007201  0.007784
# Exited           -0.016571   -0.006248    -0.027094  0.285323 -0.014001
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
# telco_base_data.corr()
# Select only numeric columns before calculating correlation
telco_base_numeric_data = telco_base_data.select_dtypes(include=np.number)
telco_base_numeric_data.corr()

# Display the correlation matrix
# print(correlation_matrix)

#If you want to include specific columns, you can do the following:
#Specify the columns you want to include in the correlation calculation
# columns_to_include = ['RowNumber', 'CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited']
# Replace with your desired columns

# Calculate correlation for selected columns
# correlation_matrix = telco_base_data[columns_to_include].corr()

# Display the correlation matrix
# print(correlation_matrix)
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000783 -0.006495
# CustomerId        0.004202    1.000000     0.005308  0.009497 -0.014883
# CreditScore       0.005840    0.005308     1.000000 -0.003965  0.000842
# Age               0.000783    0.009497    -0.003965  1.000000 -0.009997
# Tenure           -0.006495   -0.014883     0.000842 -0.009997  1.000000
# Balance          -0.009067   -0.012419     0.006268  0.028308 -0.012254
# NumOfProducts     0.007246    0.016972     0.012238 -0.030680  0.013444
# HasCrCard         0.000599   -0.014025    -0.005458 -0.011721  0.022583
# IsActiveMember    0.012044    0.001665     0.025651  0.085472 -0.028362
# EstimatedSalary  -0.005988    0.015271    -0.001384 -0.007201  0.007784
# Exited           -0.016571   -0.006248    -0.027094  0.285323 -0.014001
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
# Correlation of exited w.r.t other columns
plt.figure(figsize=(15,8))
telco_base_numeric_data.corr()['Exited'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
# sns.heatmap(telco_base_numeric_data.corr(), annot=True)
sns.heatmap(telco_base_numeric_data.corr(), annot=True, cmap='Paired')
# Out:
# <Axes: >

# %%
telco_base_data.Age.value_counts().sort_index(ascending=True).plot()
# Out:
# <Axes: xlabel='Age'>

# %%
# sns.kdeplot(data=telco_base_data, x='Age', hue='Exited')
sns.kdeplot(telco_base_data.Age[telco_base_data.Exited == 1], label='Exited', color='Red')
sns.kdeplot(telco_base_data.Age[telco_base_data.Exited == 0], label='Not Exited', fill=True)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
Tot = sns.kdeplot(telco_base_data.Balance[telco_base_data.Exited == 0], color='Blue', fill=True)
Tot = sns.kdeplot(telco_base_data.Balance[telco_base_data.Exited == 1], color='Red', fill=True)
Tot.legend(['No Churn', 'Churn'], loc='upper right')
Tot.set_ylabel('Density')
Tot.set_xlabel('Balance')
Tot.set_title('Balance by Churn')
# Out:
# Text(0.5, 1.0, 'Balance by Churn')
